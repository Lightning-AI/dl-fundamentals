# %% [markdown]
# # List resnet models from torch hub

# %%
from local_utilities import get_model_list
get_model_list()
# Out:
# ['resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152']

# %% [markdown]
# # Test TinyImageNetDatModule

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
from local_utilities import LightningModel, TinyImageNetDataModule

dm = TinyImageNetDataModule(height_width=(224, 224), batch_size=64, num_workers=0)
dm.prepare_data()
dm.setup()

#print(f'dm.train.size = {len(dm.train)}')
#for i in range(len(dm.train)):
#    img, label = dm.train[i]
#    if img.shape != (3, 224, 224):
#        print(f'image[{i}].shape = {img.shape}')
#        print(f'image[{i}].path = {dm.train.images[i]} , image[{i}].label={label}')
#    print(f'image[{i}].shape = {img.shape}, label[{i}] = {label}')
#
#print(f'dm.val.size = {len(dm.val)}')
#for i in range(len(dm.val)):
#    img, label = dm.val[i]
#    print(f'image[{i}].shape = {img.shape}, label[{i}] = {label}')


for batch, (images, labels) in enumerate(dm.val_dataloader()):  
    plt.figure(figsize=(8, 8))
    plt.axis("off")
    plt.title("Training images")
    plt.imshow(np.transpose(torchvision.utils.make_grid(
        images[:64], 
        padding=2,
        normalize=True),
        (1, 2, 0)))
    plt.show()
    # print(f"Batch {batch}: len(images) = {len(images)}, len(labels) = {len(labels)}")
    break


for batch, (images, labels) in enumerate(dm.train_dataloader()):  
    plt.figure(figsize=(8, 8))
    plt.axis("off")
    plt.title("Validation images")
    plt.imshow(np.transpose(torchvision.utils.make_grid(
        images[:64], 
        padding=2,
        normalize=True),
        (1, 2, 0)))
    plt.show()
    # print(f"Batch {batch}: len(images) = {len(images)}, len(labels) = {len(labels)}")
    break

# %% [markdown]
# # Training/Validation loss and accuracy

# %%
import matplotlib.pyplot as plt
from local_utilities import get_model_list
from PIL import Image

for metric_type in ['loss', 'acc']:
    model_list = get_model_list()
    num_rows = len(model_list)
    num_cols = 2

    fig, axs = plt.subplots(num_rows, num_cols, figsize=(num_cols * 5, num_rows * 5))
    plt.title(f"Training and validation {metric_type}")
    plt.axis("off")

    for row, resnet_type in enumerate(model_list):
        for col, augmentation in enumerate(['baseline', 'augmented']):
                title = f"tiny-imagenet-{resnet_type}-{augmentation}-{metric_type}"
                img = Image.open(f"{title}.png")
                axs[row, col].imshow(img)
                axs[row, col].set_title(title)
                axs[row, col].axis("off")
    plt.show()

# %% [markdown]
# # Test models

# %%
import lightning as L
import torch
from lightning.pytorch.loggers import CSVLogger
from local_utilities import LightningModel, TinyImageNetDataModule, get_model_list

def test_model(resnet_type, augmentation):
    model_name = f"tiny-imagenet-{resnet_type}-{augmentation}"
    print(f"testing model {model_name}")

    if augmentation == "augmented":
        augment_data = True
    else:
        augment_data = False   

    dm = TinyImageNetDataModule(height_width=(224, 224), batch_size=64, num_workers=4, augment_data=augment_data)
   
    pytorch_model = torch.hub.load('pytorch/vision', resnet_type, weights=None)
    pytorch_model.load_state_dict(torch.load(f"{model_name}.pt"))

    L.pytorch.seed_everything(123)

    lightning_model = LightningModel(model=pytorch_model, learning_rate=0.1)

    trainer = L.Trainer(
        max_epochs=50,
        accelerator="gpu",
        devices=1,
        logger=CSVLogger(save_dir="logs/", name=model_name),
        deterministic=True,
    )

    trainer.test(model=lightning_model, datamodule=dm)

model_list = get_model_list()
for model in model_list:
    test_model(model, "baseline")
    test_model(model, "augmented")
# Out:
# testing model tiny-imagenet-resnet18-baseline
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:08<00:00, 18.51it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.4458000063896179     │
# └───────────────────────────┴───────────────────────────┘
# testing model tiny-imagenet-resnet18-augmented
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:08<00:00, 18.02it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.5205000042915344     │
# └───────────────────────────┴───────────────────────────┘
# testing model tiny-imagenet-resnet34-baseline
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:08<00:00, 17.55it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.4474000036716461     │
# └───────────────────────────┴───────────────────────────┘
# testing model tiny-imagenet-resnet34-augmented
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:09<00:00, 17.16it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.5231000185012817     │
# └───────────────────────────┴───────────────────────────┘
# testing model tiny-imagenet-resnet50-baseline
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:12<00:00, 12.58it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.4223000109195709     │
# └───────────────────────────┴───────────────────────────┘
# testing model tiny-imagenet-resnet50-augmented
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:12<00:00, 12.56it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.5349000096321106     │
# └───────────────────────────┴───────────────────────────┘
# testing model tiny-imagenet-resnet101-baseline
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:17<00:00,  8.78it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.43290001153945923    │
# └───────────────────────────┴───────────────────────────┘
# testing model tiny-imagenet-resnet101-augmented
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:18<00:00,  8.61it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.5210999846458435     │
# └───────────────────────────┴───────────────────────────┘
# testing model tiny-imagenet-resnet152-baseline
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:24<00:00,  6.48it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.4162999987602234     │
# └───────────────────────────┴───────────────────────────┘
# testing model tiny-imagenet-resnet152-augmented
# Using cache found in /home/sillybierba_gmail_com/.cache/torch/hub/pytorch_vision_main
# Global seed set to 123
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 157/157 [00:24<00:00,  6.49it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │     0.524399995803833     │
# └───────────────────────────┴───────────────────────────┘
